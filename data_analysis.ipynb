# %%
import polars as pl
import duckdb as ddb

# %%
df_csv = pl.read_csv("files/mimic-iv-3.1/hosp/admissions.csv", try_parse_dates=True)
print(df_csv.head(2))
# Out:
# shape: (2, 16)
# ┌────────────┬──────────┬────────────┬────────────┬───┬───────┬────────────┬───────────┬───────────┐
# │ subject_id ┆ hadm_id  ┆ admittime  ┆ dischtime  ┆ … ┆ race  ┆ edregtime  ┆ edouttime ┆ hospital_ │
# │ ---        ┆ ---      ┆ ---        ┆ ---        ┆   ┆ ---   ┆ ---        ┆ ---       ┆ expire_fl │
# │ i64        ┆ i64      ┆ datetime[μ ┆ datetime[μ ┆   ┆ str   ┆ datetime[μ ┆ datetime[ ┆ ag        │
# │            ┆          ┆ s]         ┆ s]         ┆   ┆       ┆ s]         ┆ μs]       ┆ ---       │
# │            ┆          ┆            ┆            ┆   ┆       ┆            ┆           ┆ i64       │
# ╞════════════╪══════════╪════════════╪════════════╪═══╪═══════╪════════════╪═══════════╪═══════════╡
# │ 10000032   ┆ 22595853 ┆ 2180-05-06 ┆ 2180-05-07 ┆ … ┆ WHITE ┆ 2180-05-06 ┆ 2180-05-0 ┆ 0         │
# │            ┆          ┆ 22:23:00   ┆ 17:15:00   ┆   ┆       ┆ 19:17:00   ┆ 6         ┆           │
# ...

# %%
lazy_df = pl.scan_csv('files/mimic-iv-3.1/hosp/*.csv')

# %%
lazy_df.filter(pl.col('subject_id').is_not_null())
# Out:
# ---------------------------------------------------------------------------
# ComputeError                              Traceback (most recent call last)
# File ~/Code-Kitchen/fs-thesis/venv/lib/python3.13/site-packages/polars/lazyframe/frame.py:793, in LazyFrame._repr_html_(self)
#     792 try:
# --> 793     dot = self._ldf.to_dot(optimized=False)
#     794     svg = subprocess.check_output(
#     795         ["dot", "-Nshape=box", "-Tsvg"], input=f"{dot}".encode()
#     796     )
#
# ComputeError: schema lengths differ
#
# This error occurred with the following context stack:
# 	[1] 'csv scan'
# 	[2] 'filter'
#
#
# During handling of the above exception, another exception occurred:
#
# ComputeError                              Traceback (most recent call last)
# File ~/Code-Kitchen/fs-thesis/venv/lib/python3.13/site-packages/IPython/core/formatters.py:406, in BaseFormatter.__call__(self, obj)
#     404     method = get_real_method(obj, self.print_method)
# ...
