# %%
import duckdb as ddb
import os
from glob import glob

conn = ddb.connect(database="mimic_v2.db")

paths = {
    'ed': 'files/ed',
    'hosp': 'files/hosp',
    'icu': 'files/icu',
}

for schema, path in paths.items():
    # create schema if not exists
    conn.execute(f"CREATE SCHEMA IF NOT EXISTS {schema};")
    csv_files = sorted(glob(os.path.join(path, '*.csv')))
    print(f"Found {len(csv_files)} csv files in {path} for schema {schema}")
    for p in csv_files:
        # derive a safe view name from filename
        fname = os.path.splitext(os.path.basename(p))[0]
        view_name = ''.join(c if c.isalnum() else '_' for c in fname).lower()
        full_view = f"{schema}.{view_name}"
        # create or replace view pointing to the CSV
        sql = f"CREATE OR REPLACE VIEW {full_view} AS SELECT * FROM read_csv_auto('{p}');"
        try:
            conn.execute(sql)
            print(f"Created view {full_view} -> {p}")
        except Exception as e:
            print(f"Failed to create view {full_view} for {p}: {e}")

print('Finished creating views.')
# Out:
# Found 6 csv files in files/ed for schema ed
# Created view ed.diagnosis -> files/ed/diagnosis.csv
# Created view ed.edstays -> files/ed/edstays.csv
# Created view ed.medrecon -> files/ed/medrecon.csv
# Created view ed.pyxis -> files/ed/pyxis.csv
# Created view ed.triage -> files/ed/triage.csv
# Created view ed.vitalsign -> files/ed/vitalsign.csv
# Found 22 csv files in files/hosp for schema hosp
# Created view hosp.admissions -> files/hosp/admissions.csv
# Created view hosp.d_hcpcs -> files/hosp/d_hcpcs.csv
# Created view hosp.d_icd_diagnoses -> files/hosp/d_icd_diagnoses.csv
# Created view hosp.d_icd_procedures -> files/hosp/d_icd_procedures.csv
# Created view hosp.d_labitems -> files/hosp/d_labitems.csv
# Created view hosp.diagnoses_icd -> files/hosp/diagnoses_icd.csv
# Created view hosp.drgcodes -> files/hosp/drgcodes.csv
# Created view hosp.emar -> files/hosp/emar.csv
# Created view hosp.emar_detail -> files/hosp/emar_detail.csv
# Created view hosp.hcpcsevents -> files/hosp/hcpcsevents.csv
# Created view hosp.labevents -> files/hosp/labevents.csv
# Created view hosp.microbiologyevents -> files/hosp/microbiologyevents.csv
# Created view hosp.omr -> files/hosp/omr.csv
# Created view hosp.patients -> files/hosp/patients.csv
# Created view hosp.pharmacy -> files/hosp/pharmacy.csv
# Created view hosp.poe -> files/hosp/poe.csv
# Created view hosp.poe_detail -> files/hosp/poe_detail.csv
# Created view hosp.prescriptions -> files/hosp/prescriptions.csv
# Created view hosp.procedures_icd -> files/hosp/procedures_icd.csv
# Created view hosp.provider -> files/hosp/provider.csv
# Created view hosp.services -> files/hosp/services.csv
# Created view hosp.transfers -> files/hosp/transfers.csv
# Found 9 csv files in files/icu for schema icu
# Created view icu.caregiver -> files/icu/caregiver.csv
# Created view icu.chartevents -> files/icu/chartevents.csv
# Created view icu.d_items -> files/icu/d_items.csv
# Created view icu.datetimeevents -> files/icu/datetimeevents.csv
# Created view icu.icustays -> files/icu/icustays.csv
# Created view icu.ingredientevents -> files/icu/ingredientevents.csv
# Created view icu.inputevents -> files/icu/inputevents.csv
# Created view icu.outputevents -> files/icu/outputevents.csv
# Created view icu.procedureevents -> files/icu/procedureevents.csv
# Finished creating views.

# %%
import duckdb
import polars as pl

# Verbindung herstellen oder Datei anlegen
con = duckdb.connect("mimic_v2.db")

# SQL
df = con.execute("SHOW ALL TABLES").df()
display(df)
# Out:
#     database schema                name  \
# 0   mimic_v2     ed           diagnosis
# 1   mimic_v2     ed             edstays
# 2   mimic_v2     ed            medrecon
# 3   mimic_v2     ed               pyxis
# 4   mimic_v2     ed              triage
# 5   mimic_v2     ed           vitalsign
# 6   mimic_v2   hosp          admissions
# 7   mimic_v2   hosp             d_hcpcs
# 8   mimic_v2   hosp     d_icd_diagnoses
# 9   mimic_v2   hosp    d_icd_procedures
# 10  mimic_v2   hosp          d_labitems
# 11  mimic_v2   hosp       diagnoses_icd
# 12  mimic_v2   hosp            drgcodes
# 13  mimic_v2   hosp                emar
# 14  mimic_v2   hosp         emar_detail
# 15  mimic_v2   hosp         hcpcsevents
# 16  mimic_v2   hosp           labevents
# 17  mimic_v2   hosp  microbiologyevents
# 18  mimic_v2   hosp                 omr
# 19  mimic_v2   hosp            patients
# 20  mimic_v2   hosp            pharmacy
# 21  mimic_v2   hosp                 poe
# 22  mimic_v2   hosp          poe_detail
# 23  mimic_v2   hosp       prescriptions
# 24  mimic_v2   hosp      procedures_icd
# 25  mimic_v2   hosp            provider
# 26  mimic_v2   hosp            services
# 27  mimic_v2   hosp           transfers
# 28  mimic_v2    icu           caregiver
# 29  mimic_v2    icu         chartevents
# 30  mimic_v2    icu             d_items
# 31  mimic_v2    icu      datetimeevents
# 32  mimic_v2    icu            icustays
# 33  mimic_v2    icu    ingredientevents
# 34  mimic_v2    icu         inputevents
# 35  mimic_v2    icu        outputevents
# 36  mimic_v2    icu     procedureevents
#
#                                          column_names  \
# 0   [subject_id, stay_id, seq_num, icd_code, icd_v...
# 1   [subject_id, hadm_id, stay_id, intime, outtime...
# 2   [subject_id, stay_id, charttime, name, gsn, nd...
# 3   [subject_id, stay_id, charttime, med_rn, name,...
# 4   [subject_id, stay_id, temperature, heartrate, ...
# 5   [subject_id, stay_id, charttime, temperature, ...
# 6   [subject_id, hadm_id, admittime, dischtime, de...
# 7   [code, category, long_description, short_descr...
# 8                 [icd_code, icd_version, long_title]
# 9                 [icd_code, icd_version, long_title]
# 10                   [itemid, label, fluid, category]
# 11  [subject_id, hadm_id, seq_num, icd_code, icd_v...
# 12  [subject_id, hadm_id, drg_type, drg_code, desc...
# 13  [subject_id, hadm_id, emar_id, emar_seq, poe_i...
# 14  [subject_id, emar_id, emar_seq, parent_field_o...
# 15  [subject_id, hadm_id, chartdate, hcpcs_cd, seq...
# 16  [labevent_id, subject_id, hadm_id, specimen_id...
# 17  [microevent_id, subject_id, hadm_id, micro_spe...
# 18  [subject_id, chartdate, seq_num, result_name, ...
# 19  [subject_id, gender, anchor_age, anchor_year, ...
# 20  [subject_id, hadm_id, pharmacy_id, poe_id, sta...
# 21  [poe_id, poe_seq, subject_id, hadm_id, orderti...
# 22  [poe_id, poe_seq, subject_id, field_name, fiel...
# 23  [subject_id, hadm_id, pharmacy_id, poe_id, poe...
# 24  [subject_id, hadm_id, seq_num, chartdate, icd_...
# 25                                      [provider_id]
# 26  [subject_id, hadm_id, transfertime, prev_servi...
# 27  [subject_id, hadm_id, transfer_id, eventtype, ...
# 28                                     [caregiver_id]
# 29  [subject_id, hadm_id, stay_id, caregiver_id, c...
# 30  [itemid, label, abbreviation, linksto, categor...
# 31  [subject_id, hadm_id, stay_id, caregiver_id, c...
# 32  [subject_id, hadm_id, stay_id, first_careunit,...
# 33  [subject_id, hadm_id, stay_id, caregiver_id, s...
# 34  [subject_id, hadm_id, stay_id, caregiver_id, s...
# 35  [subject_id, hadm_id, stay_id, caregiver_id, c...
# 36  [subject_id, hadm_id, stay_id, caregiver_id, s...
#
#                                          column_types  temporary
# 0   [BIGINT, BIGINT, BIGINT, VARCHAR, BIGINT, VARC...      False
# 1   [BIGINT, BIGINT, BIGINT, TIMESTAMP, TIMESTAMP,...      False
# 2   [BIGINT, BIGINT, TIMESTAMP, VARCHAR, VARCHAR, ...      False
# 3   [BIGINT, BIGINT, TIMESTAMP, BIGINT, VARCHAR, B...      False
# 4   [BIGINT, BIGINT, DOUBLE, DOUBLE, DOUBLE, DOUBL...      False
# 5   [BIGINT, BIGINT, TIMESTAMP, DOUBLE, DOUBLE, DO...      False
# 6   [BIGINT, BIGINT, TIMESTAMP, TIMESTAMP, TIMESTA...      False
# 7                 [VARCHAR, BIGINT, VARCHAR, VARCHAR]      False
# 8                          [VARCHAR, BIGINT, VARCHAR]      False
# 9                          [VARCHAR, BIGINT, VARCHAR]      False
# 10                [BIGINT, VARCHAR, VARCHAR, VARCHAR]      False
# 11          [BIGINT, BIGINT, BIGINT, VARCHAR, BIGINT]      False
# 12  [BIGINT, BIGINT, VARCHAR, VARCHAR, VARCHAR, BI...      False
# 13  [BIGINT, BIGINT, VARCHAR, BIGINT, VARCHAR, BIG...      False
# 14  [BIGINT, VARCHAR, BIGINT, DOUBLE, VARCHAR, BIG...      False
# 15   [BIGINT, BIGINT, DATE, VARCHAR, BIGINT, VARCHAR]      False
# 16  [BIGINT, BIGINT, BIGINT, BIGINT, BIGINT, VARCH...      False
# 17  [BIGINT, BIGINT, BIGINT, BIGINT, VARCHAR, TIME...      False
# 18           [BIGINT, DATE, BIGINT, VARCHAR, VARCHAR]      False
# 19   [BIGINT, VARCHAR, BIGINT, BIGINT, VARCHAR, DATE]      False
# 20  [BIGINT, BIGINT, BIGINT, VARCHAR, TIMESTAMP, T...      False
# 21  [VARCHAR, BIGINT, BIGINT, BIGINT, TIMESTAMP, V...      False
# 22        [VARCHAR, BIGINT, BIGINT, VARCHAR, VARCHAR]      False
# 23  [BIGINT, BIGINT, BIGINT, VARCHAR, BIGINT, VARC...      False
# 24    [BIGINT, BIGINT, BIGINT, DATE, VARCHAR, BIGINT]      False
# 25                                          [VARCHAR]      False
# 26      [BIGINT, BIGINT, TIMESTAMP, VARCHAR, VARCHAR]      False
# 27  [BIGINT, BIGINT, BIGINT, VARCHAR, VARCHAR, TIM...      False
# 28                                           [BIGINT]      False
# 29  [BIGINT, BIGINT, BIGINT, BIGINT, TIMESTAMP, TI...      False
# 30  [BIGINT, VARCHAR, VARCHAR, VARCHAR, VARCHAR, V...      False
# 31  [BIGINT, BIGINT, BIGINT, BIGINT, TIMESTAMP, TI...      False
# 32  [BIGINT, BIGINT, BIGINT, VARCHAR, VARCHAR, TIM...      False
# 33  [BIGINT, BIGINT, BIGINT, BIGINT, TIMESTAMP, TI...      False
# 34  [BIGINT, BIGINT, BIGINT, BIGINT, TIMESTAMP, TI...      False
# 35  [BIGINT, BIGINT, BIGINT, BIGINT, TIMESTAMP, TI...      False
# 36  [BIGINT, BIGINT, BIGINT, BIGINT, TIMESTAMP, TI...      False

# %%
con.execute("SELECT * FROM ed.diagnosis LIMIT 5").df()
# Out:
#    subject_id   stay_id  seq_num icd_code  icd_version  \
# 0    10000032  32952584        1     4589            9
# 1    10000032  32952584        2    07070            9
# 2    10000032  32952584        3      V08            9
# 3    10000032  33258284        1     5728            9
# 4    10000032  33258284        2    78959            9
#
#                                            icd_title
# 0                                    HYPOTENSION NOS
# 1  UNSPECIFIED VIRAL HEPATITIS C WITHOUT HEPATIC ...
# 2                         ASYMPTOMATIC HIV INFECTION
# 3                           OTH SEQUELA, CHR LIV DIS
# 4                                      OTHER ASCITES
