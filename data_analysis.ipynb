# %% [markdown]
# # Install Packages

# %%
# !pip install duckdb glob2 polars pyarrow
# Out:
# Requirement already satisfied: duckdb in ./venv/lib/python3.13/site-packages (1.4.1)
# Requirement already satisfied: glob2 in ./venv/lib/python3.13/site-packages (0.7)
# Requirement already satisfied: polars in ./venv/lib/python3.13/site-packages (1.34.0)
# Requirement already satisfied: pyarrow in ./venv/lib/python3.13/site-packages (21.0.0)
# Requirement already satisfied: polars-runtime-32==1.34.0 in ./venv/lib/python3.13/site-packages (from polars) (1.34.0)
#
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: pip install --upgrade pip
#
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: pip install --upgrade pip

# %% [markdown]
# # Create views

# %%
import duckdb as ddb
import os
from glob import glob

# Schritt 1: Verbindung zum Erstellen der Views
con = ddb.connect(database="mimic_v2.db")
count = 0

paths = {
    'ed': 'files/ed',
    'hosp': 'files/hosp',
    'icu': 'files/icu',
}

try:
    for schema, path in paths.items():
        # create schema if not exists
        con.execute(f"CREATE SCHEMA IF NOT EXISTS {schema};")
        csv_files = sorted(glob(os.path.join(path, '*.csv')))
        print(f"Found {len(csv_files)} csv files in {path} for schema {schema}")
        for p in csv_files:
            count += 1
            # derive a safe view name from filename
            fname = os.path.splitext(os.path.basename(p))[0]
            view_name = ''.join(c if c.isalnum() else '_' for c in fname).lower()
            full_view = f"{schema}.{view_name}"
            # create or replace view pointing to the CSV
            sql = f"CREATE OR REPLACE VIEW {full_view} AS SELECT * FROM read_csv_auto('{p}');"
            try:
                con.execute(sql)
                print(f"View-Nr.:{count} Created view {full_view} -> {p}")
            except Exception as e:
                print(f"Failed to create view {full_view} for {p}: {e}")
finally:
    # Sauber schließen
    con.close()
    print('Views erstellt und Verbindung geschlossen.')

# Schritt 2: Read-only Verbindung öffnen
con = ddb.connect(database="mimic_v2.db", read_only=True)
print('Read-only Verbindung geöffnet.')
# Out:
# Found 6 csv files in files/ed for schema ed
# View-Nr.:1 Created view ed.diagnosis -> files/ed/diagnosis.csv
# View-Nr.:1 Created view ed.diagnosis -> files/ed/diagnosis.csv
# View-Nr.:2 Created view ed.edstays -> files/ed/edstays.csv
# View-Nr.:3 Created view ed.medrecon -> files/ed/medrecon.csv
# View-Nr.:4 Created view ed.pyxis -> files/ed/pyxis.csv
# View-Nr.:5 Created view ed.triage -> files/ed/triage.csv
# View-Nr.:2 Created view ed.edstays -> files/ed/edstays.csv
# View-Nr.:3 Created view ed.medrecon -> files/ed/medrecon.csv
# View-Nr.:4 Created view ed.pyxis -> files/ed/pyxis.csv
# View-Nr.:5 Created view ed.triage -> files/ed/triage.csv
# View-Nr.:6 Created view ed.vitalsign -> files/ed/vitalsign.csv
# Found 22 csv files in files/hosp for schema hosp
# View-Nr.:6 Created view ed.vitalsign -> files/ed/vitalsign.csv
# Found 22 csv files in files/hosp for schema hosp
# View-Nr.:7 Created view hosp.admissions -> files/hosp/admissions.csv
# View-Nr.:8 Created view hosp.d_hcpcs -> files/hosp/d_hcpcs.csv
# View-Nr.:9 Created view hosp.d_icd_diagnoses -> files/hosp/d_icd_diagnoses.csv
# View-Nr.:10 Created view hosp.d_icd_procedures -> files/hosp/d_icd_procedures.csv
# View-Nr.:11 Created view hosp.d_labitems -> files/hosp/d_labitems.csv
# View-Nr.:12 Created view hosp.diagnoses_icd -> files/hosp/diagnoses_icd.csv
# View-Nr.:7 Created view hosp.admissions -> files/hosp/admissions.csv
# View-Nr.:8 Created view hosp.d_hcpcs -> files/hosp/d_hcpcs.csv
# View-Nr.:9 Created view hosp.d_icd_diagnoses -> files/hosp/d_icd_diagnoses.csv
# View-Nr.:10 Created view hosp.d_icd_procedures -> files/hosp/d_icd_procedures.csv
# View-Nr.:11 Created view hosp.d_labitems -> files/hosp/d_labitems.csv
# View-Nr.:12 Created view hosp.diagnoses_icd -> files/hosp/diagnoses_icd.csv
# View-Nr.:13 Created view hosp.drgcodes -> files/hosp/drgcodes.csv
# View-Nr.:14 Created view hosp.emar -> files/hosp/emar.csv
# View-Nr.:13 Created view hosp.drgcodes -> files/hosp/drgcodes.csv
# View-Nr.:14 Created view hosp.emar -> files/hosp/emar.csv
# View-Nr.:15 Created view hosp.emar_detail -> files/hosp/emar_detail.csv
# View-Nr.:16 Created view hosp.hcpcsevents -> files/hosp/hcpcsevents.csv
# View-Nr.:17 Created view hosp.labevents -> files/hosp/labevents.csv
# View-Nr.:15 Created view hosp.emar_detail -> files/hosp/emar_detail.csv
# View-Nr.:16 Created view hosp.hcpcsevents -> files/hosp/hcpcsevents.csv
# View-Nr.:17 Created view hosp.labevents -> files/hosp/labevents.csv
# View-Nr.:18 Created view hosp.microbiologyevents -> files/hosp/microbiologyevents.csv
# View-Nr.:19 Created view hosp.omr -> files/hosp/omr.csv
# View-Nr.:18 Created view hosp.microbiologyevents -> files/hosp/microbiologyevents.csv
# View-Nr.:19 Created view hosp.omr -> files/hosp/omr.csv
# View-Nr.:20 Created view hosp.patients -> files/hosp/patients.csv
# View-Nr.:21 Created view hosp.pharmacy -> files/hosp/pharmacy.csv
# View-Nr.:22 Created view hosp.poe -> files/hosp/poe.csv
# View-Nr.:23 Created view hosp.poe_detail -> files/hosp/poe_detail.csv
# View-Nr.:20 Created view hosp.patients -> files/hosp/patients.csv
# View-Nr.:21 Created view hosp.pharmacy -> files/hosp/pharmacy.csv
# View-Nr.:22 Created view hosp.poe -> files/hosp/poe.csv
# View-Nr.:23 Created view hosp.poe_detail -> files/hosp/poe_detail.csv
# View-Nr.:24 Created view hosp.prescriptions -> files/hosp/prescriptions.csv
# View-Nr.:25 Created view hosp.procedures_icd -> files/hosp/procedures_icd.csv
# View-Nr.:26 Created view hosp.provider -> files/hosp/provider.csv
# View-Nr.:27 Created view hosp.services -> files/hosp/services.csv
# View-Nr.:28 Created view hosp.transfers -> files/hosp/transfers.csv
# Found 9 csv files in files/icu for schema icu
# View-Nr.:29 Created view icu.caregiver -> files/icu/caregiver.csv
# View-Nr.:30 Created view icu.chartevents -> files/icu/chartevents.csv
# View-Nr.:31 Created view icu.d_items -> files/icu/d_items.csv
# View-Nr.:24 Created view hosp.prescriptions -> files/hosp/prescriptions.csv
# View-Nr.:25 Created view hosp.procedures_icd -> files/hosp/procedures_icd.csv
# View-Nr.:26 Created view hosp.provider -> files/hosp/provider.csv
# View-Nr.:27 Created view hosp.services -> files/hosp/services.csv
# View-Nr.:28 Created view hosp.transfers -> files/hosp/transfers.csv
# Found 9 csv files in files/icu for schema icu
# View-Nr.:29 Created view icu.caregiver -> files/icu/caregiver.csv
# View-Nr.:30 Created view icu.chartevents -> files/icu/chartevents.csv
# View-Nr.:31 Created view icu.d_items -> files/icu/d_items.csv
# View-Nr.:32 Created view icu.datetimeevents -> files/icu/datetimeevents.csv
# View-Nr.:33 Created view icu.icustays -> files/icu/icustays.csv
# View-Nr.:34 Created view icu.ingredientevents -> files/icu/ingredientevents.csv
# View-Nr.:32 Created view icu.datetimeevents -> files/icu/datetimeevents.csv
# View-Nr.:33 Created view icu.icustays -> files/icu/icustays.csv
# View-Nr.:34 Created view icu.ingredientevents -> files/icu/ingredientevents.csv
# View-Nr.:35 Created view icu.inputevents -> files/icu/inputevents.csv
# View-Nr.:36 Created view icu.outputevents -> files/icu/outputevents.csv
# View-Nr.:37 Created view icu.procedureevents -> files/icu/procedureevents.csv
# Views erstellt und Verbindung geschlossen.
# Read-only Verbindung geöffnet.
# View-Nr.:35 Created view icu.inputevents -> files/icu/inputevents.csv
# View-Nr.:36 Created view icu.outputevents -> files/icu/outputevents.csv
# View-Nr.:37 Created view icu.procedureevents -> files/icu/procedureevents.csv
# Views erstellt und Verbindung geschlossen.
# Read-only Verbindung geöffnet.

# %% [markdown]
# # Helper Functions

# %%
import polars as pl
import pandas as pd

# sql helper function
def sql(q: str):
    """Run a sql query on the open DuckDB connection and return a Polars DataFrame."""
    pl.Config.set_tbl_rows(-1)
    pl.Config.set_tbl_cols(-1)
    try:
        return con.execute(q).pl()
    except Exception as e:
        print(f"SQL query failed: {e}")
        return pl.DataFrame()
    
def show(df: pl.DataFrame, limit: bool = False):
    """Display a Polars DataFrame with configurable column width and row limit."""
    if limit:
        pd.set_option("display.max_colwidth", 50)
        pd.set_option("display.max_rows", 20)
    else:
        pd.set_option("display.max_colwidth", None)
        pd.set_option("display.max_rows", None)
    display(df.to_pandas())

# %% [markdown]
# # Overview & Metadata

# %%
# SQL
df = sql("SHOW ALL TABLES")
show(df)
# Out:
#     database schema                name  \
# 0   mimic_v2     ed           diagnosis
# 1   mimic_v2     ed             edstays
# 2   mimic_v2     ed            medrecon
# 3   mimic_v2     ed               pyxis
# 4   mimic_v2     ed              triage
# 5   mimic_v2     ed           vitalsign
# 6   mimic_v2   hosp          admissions
# 7   mimic_v2   hosp             d_hcpcs
# 8   mimic_v2   hosp     d_icd_diagnoses
# 9   mimic_v2   hosp    d_icd_procedures
# 10  mimic_v2   hosp          d_labitems
# 11  mimic_v2   hosp       diagnoses_icd
# 12  mimic_v2   hosp            drgcodes
# 13  mimic_v2   hosp                emar
# 14  mimic_v2   hosp         emar_detail
# 15  mimic_v2   hosp         hcpcsevents
# 16  mimic_v2   hosp           labevents
# 17  mimic_v2   hosp  microbiologyevents
# 18  mimic_v2   hosp                 omr
# 19  mimic_v2   hosp            patients
# 20  mimic_v2   hosp            pharmacy
# 21  mimic_v2   hosp                 poe
# 22  mimic_v2   hosp          poe_detail
# 23  mimic_v2   hosp       prescriptions
# 24  mimic_v2   hosp      procedures_icd
# 25  mimic_v2   hosp            provider
# 26  mimic_v2   hosp            services
# 27  mimic_v2   hosp           transfers
# 28  mimic_v2    icu           caregiver
# 29  mimic_v2    icu         chartevents
# 30  mimic_v2    icu             d_items
# 31  mimic_v2    icu      datetimeevents
# 32  mimic_v2    icu            icustays
# 33  mimic_v2    icu    ingredientevents
# 34  mimic_v2    icu         inputevents
# 35  mimic_v2    icu        outputevents
# 36  mimic_v2    icu     procedureevents
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 column_names  \
# 0                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           [subject_id, stay_id, seq_num, icd_code, icd_version, icd_title]
# 1                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              [subject_id, hadm_id, stay_id, intime, outtime, gender, race, arrival_transport, disposition]
# 2                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          [subject_id, stay_id, charttime, name, gsn, ndc, etc_rn, etccode, etcdescription]
# 3                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                [subject_id, stay_id, charttime, med_rn, name, gsn_rn, gsn]
# 4                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     [subject_id, stay_id, temperature, heartrate, resprate, o2sat, sbp, dbp, pain, acuity, chiefcomplaint]
# 5                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          [subject_id, stay_id, charttime, temperature, heartrate, resprate, o2sat, sbp, dbp, rhythm, pain]
# 6                                                                                                                                                                                                                                                                                                                                                                                                                   [subject_id, hadm_id, admittime, dischtime, deathtime, admission_type, admit_provider_id, admission_location, discharge_location, insurance, language, marital_status, race, edregtime, edouttime, hospital_expire_flag]
# 7                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      [code, category, long_description, short_description]
# 8                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        [icd_code, icd_version, long_title]
# 9                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        [icd_code, icd_version, long_title]
# 10                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          [itemid, label, fluid, category]
# 11                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     [subject_id, hadm_id, seq_num, icd_code, icd_version]
# 12                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       [subject_id, hadm_id, drg_type, drg_code, description, drg_severity, drg_mortality]
# 13                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               [subject_id, hadm_id, emar_id, emar_seq, poe_id, pharmacy_id, enter_provider_id, charttime, medication, event_txt, scheduletime, storetime]
# 14  [subject_id, emar_id, emar_seq, parent_field_ordinal, administration_type, pharmacy_id, barcode_type, reason_for_no_barcode, complete_dose_not_given, dose_due, dose_due_unit, dose_given, dose_given_unit, will_remainder_of_dose_be_given, product_amount_given, product_unit, product_code, product_description, product_description_other, prior_infusion_rate, infusion_rate, infusion_rate_adjustment, infusion_rate_adjustment_amount, infusion_rate_unit, route, infusion_complete, completion_interval, new_iv_bag_hung, continued_infusion_in_other_location, restart_interval, side, site, non_formulary_visual_verification]
# 15                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    [subject_id, hadm_id, chartdate, hcpcs_cd, seq_num, short_description]
# 16                                                                                                                                                                                                                                                                                                                                                                                                                                                   [labevent_id, subject_id, hadm_id, specimen_id, itemid, order_provider_id, charttime, storetime, value, valuenum, valueuom, ref_range_lower, ref_range_upper, flag, priority, comments]
# 17                                                                                                                                                                                                                                                                                                      [microevent_id, subject_id, hadm_id, micro_specimen_id, order_provider_id, chartdate, charttime, spec_itemid, spec_type_desc, test_seq, storedate, storetime, test_itemid, test_name, org_itemid, org_name, isolate_num, quantity, ab_itemid, ab_name, dilution_text, dilution_comparison, dilution_value, interpretation, comments]
# 18                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               [subject_id, chartdate, seq_num, result_name, result_value]
# 19                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     [subject_id, gender, anchor_age, anchor_year, anchor_year_group, dod]
# 20                                                                                                                                                                                                                                                                              [subject_id, hadm_id, pharmacy_id, poe_id, starttime, stoptime, medication, proc_type, status, entertime, verifiedtime, route, frequency, disp_sched, infusion_type, sliding_scale, lockout_interval, basal_rate, one_hr_max, doses_per_24_hrs, duration, duration_interval, expiration_value, expiration_unit, expirationdate, dispensation, fill_quantity]
# 21                                                                                                                                                                                                                                                                                                                                                                                                                                                            [poe_id, poe_seq, subject_id, hadm_id, ordertime, order_type, order_subtype, transaction_type, discontinue_of_poe_id, discontinued_by_poe_id, order_provider_id, order_status]
# 22                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    [poe_id, poe_seq, subject_id, field_name, field_value]
# 23                                                                                                                                                                                                                                                                                                                                                                                      [subject_id, hadm_id, pharmacy_id, poe_id, poe_seq, order_provider_id, starttime, stoptime, drug_type, drug, formulary_drug_cd, gsn, ndc, prod_strength, form_rx, dose_val_rx, dose_unit_rx, form_val_disp, form_unit_disp, doses_per_24_hrs, route]
# 24                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          [subject_id, hadm_id, seq_num, chartdate, icd_code, icd_version]
# 25                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             [provider_id]
# 26                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           [subject_id, hadm_id, transfertime, prev_service, curr_service]
# 27                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  [subject_id, hadm_id, transfer_id, eventtype, careunit, intime, outtime]
# 28                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            [caregiver_id]
# 29                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            [subject_id, hadm_id, stay_id, caregiver_id, charttime, storetime, itemid, value, valuenum, valueuom, warning]
# 30                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   [itemid, label, abbreviation, linksto, category, unitname, param_type, lownormalvalue, highnormalvalue]
# 31                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      [subject_id, hadm_id, stay_id, caregiver_id, charttime, storetime, itemid, value, valueuom, warning]
# 32                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       [subject_id, hadm_id, stay_id, first_careunit, last_careunit, intime, outtime, los]
# 33                                                                                                                                                                                                                                                                                                                                                                                                                                              [subject_id, hadm_id, stay_id, caregiver_id, starttime, endtime, storetime, itemid, amount, amountuom, rate, rateuom, orderid, linkorderid, statusdescription, originalamount, originalrate]
# 34                                                                                                                                                                                                                                                           [subject_id, hadm_id, stay_id, caregiver_id, starttime, endtime, storetime, itemid, amount, amountuom, rate, rateuom, orderid, linkorderid, ordercategoryname, secondaryordercategoryname, ordercomponenttypedescription, ordercategorydescription, patientweight, totalamount, totalamountuom, isopenbag, continueinnextdept, statusdescription, originalamount, originalrate]
# 35                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               [subject_id, hadm_id, stay_id, caregiver_id, charttime, storetime, itemid, value, valueuom]
# 36                                                                                                                                                                                                                                                                                                                                        [subject_id, hadm_id, stay_id, caregiver_id, starttime, endtime, storetime, itemid, value, valueuom, location, locationcategory, orderid, linkorderid, ordercategoryname, ordercategorydescription, patientweight, isopenbag, continueinnextdept, statusdescription, originalamount, originalrate]
#
#                                                                                                                                                                                                                                                                                          column_types  \
# 0                                                                                                                                                                                                                                                  [BIGINT, BIGINT, BIGINT, VARCHAR, BIGINT, VARCHAR]
# 1                                                                                                                                                                                                                  [BIGINT, BIGINT, BIGINT, TIMESTAMP, TIMESTAMP, VARCHAR, VARCHAR, VARCHAR, VARCHAR]
# 2                                                                                                                                                                                                                    [BIGINT, BIGINT, TIMESTAMP, VARCHAR, VARCHAR, VARCHAR, BIGINT, VARCHAR, VARCHAR]
# 3                                                                                                                                                                                                                                       [BIGINT, BIGINT, TIMESTAMP, BIGINT, VARCHAR, BIGINT, VARCHAR]
# 4                                                                                                                                                                                                          [BIGINT, BIGINT, DOUBLE, DOUBLE, DOUBLE, DOUBLE, DOUBLE, DOUBLE, VARCHAR, DOUBLE, VARCHAR]
# 5                                                                                                                                                                                                       [BIGINT, BIGINT, TIMESTAMP, DOUBLE, DOUBLE, DOUBLE, DOUBLE, BIGINT, BIGINT, VARCHAR, VARCHAR]
# 6                                                                                                                                             [BIGINT, BIGINT, TIMESTAMP, TIMESTAMP, TIMESTAMP, VARCHAR, VARCHAR, VARCHAR, VARCHAR, VARCHAR, VARCHAR, VARCHAR, VARCHAR, TIMESTAMP, TIMESTAMP, BIGINT]
# 7                                                                                                                                                                                                                                                                 [VARCHAR, BIGINT, VARCHAR, VARCHAR]
# 8                                                                                                                                                                                                                                                                          [VARCHAR, BIGINT, VARCHAR]
# 9                                                                                                                                                                                                                                                                          [VARCHAR, BIGINT, VARCHAR]
# 10                                                                                                                                                                                                                                                                [BIGINT, VARCHAR, VARCHAR, VARCHAR]
# 11                                                                                                                                                                                                                                                          [BIGINT, BIGINT, BIGINT, VARCHAR, BIGINT]
# 12                                                                                                                                                                                                                                        [BIGINT, BIGINT, VARCHAR, VARCHAR, VARCHAR, BIGINT, BIGINT]
# 13                                                                                                                                                                                     [BIGINT, BIGINT, VARCHAR, BIGINT, VARCHAR, BIGINT, VARCHAR, TIMESTAMP, VARCHAR, VARCHAR, TIMESTAMP, TIMESTAMP]
# 14  [BIGINT, VARCHAR, BIGINT, DOUBLE, VARCHAR, BIGINT, VARCHAR, VARCHAR, BOOLEAN, VARCHAR, VARCHAR, VARCHAR, VARCHAR, BOOLEAN, DOUBLE, VARCHAR, VARCHAR, VARCHAR, VARCHAR, DOUBLE, DOUBLE, VARCHAR, BIGINT, VARCHAR, VARCHAR, VARCHAR, VARCHAR, VARCHAR, VARCHAR, VARCHAR, VARCHAR, VARCHAR, VARCHAR]
# 15                                                                                                                                                                                                                                                   [BIGINT, BIGINT, DATE, VARCHAR, BIGINT, VARCHAR]
# 16                                                                                                                                                       [BIGINT, BIGINT, BIGINT, BIGINT, BIGINT, VARCHAR, TIMESTAMP, TIMESTAMP, VARCHAR, DOUBLE, VARCHAR, DOUBLE, DOUBLE, VARCHAR, VARCHAR, VARCHAR]
# 17                                                                     [BIGINT, BIGINT, BIGINT, BIGINT, VARCHAR, TIMESTAMP, TIMESTAMP, BIGINT, VARCHAR, BIGINT, TIMESTAMP, TIMESTAMP, BIGINT, VARCHAR, BIGINT, VARCHAR, BIGINT, VARCHAR, BIGINT, VARCHAR, VARCHAR, VARCHAR, DOUBLE, VARCHAR, VARCHAR]
# 18                                                                                                                                                                                                                                                           [BIGINT, DATE, BIGINT, VARCHAR, VARCHAR]
# 19                                                                                                                                                                                                                                                   [BIGINT, VARCHAR, BIGINT, BIGINT, VARCHAR, DATE]
# 20                                                [BIGINT, BIGINT, BIGINT, VARCHAR, TIMESTAMP, TIMESTAMP, VARCHAR, VARCHAR, VARCHAR, TIMESTAMP, TIMESTAMP, VARCHAR, VARCHAR, VARCHAR, VARCHAR, VARCHAR, BIGINT, DOUBLE, DOUBLE, BIGINT, BIGINT, VARCHAR, BIGINT, VARCHAR, TIMESTAMP, VARCHAR, BIGINT]
# 21                                                                                                                                                                                        [VARCHAR, BIGINT, BIGINT, BIGINT, TIMESTAMP, VARCHAR, VARCHAR, VARCHAR, VARCHAR, VARCHAR, VARCHAR, VARCHAR]
# 22                                                                                                                                                                                                                                                        [VARCHAR, BIGINT, BIGINT, VARCHAR, VARCHAR]
# 23                                                                                                       [BIGINT, BIGINT, BIGINT, VARCHAR, BIGINT, VARCHAR, TIMESTAMP, TIMESTAMP, VARCHAR, VARCHAR, VARCHAR, VARCHAR, VARCHAR, VARCHAR, VARCHAR, VARCHAR, VARCHAR, VARCHAR, VARCHAR, BIGINT, VARCHAR]
# 24                                                                                                                                                                                                                                                    [BIGINT, BIGINT, BIGINT, DATE, VARCHAR, BIGINT]
# 25                                                                                                                                                                                                                                                                                          [VARCHAR]
# 26                                                                                                                                                                                                                                                      [BIGINT, BIGINT, TIMESTAMP, VARCHAR, VARCHAR]
# 27                                                                                                                                                                                                                                   [BIGINT, BIGINT, BIGINT, VARCHAR, VARCHAR, TIMESTAMP, TIMESTAMP]
# 28                                                                                                                                                                                                                                                                                           [BIGINT]
# 29                                                                                                                                                                                                   [BIGINT, BIGINT, BIGINT, BIGINT, TIMESTAMP, TIMESTAMP, BIGINT, VARCHAR, DOUBLE, VARCHAR, BIGINT]
# 30                                                                                                                                                                                                                     [BIGINT, VARCHAR, VARCHAR, VARCHAR, VARCHAR, VARCHAR, VARCHAR, BIGINT, DOUBLE]
# 31                                                                                                                                                                                                         [BIGINT, BIGINT, BIGINT, BIGINT, TIMESTAMP, TIMESTAMP, BIGINT, TIMESTAMP, VARCHAR, BIGINT]
# 32                                                                                                                                                                                                                           [BIGINT, BIGINT, BIGINT, VARCHAR, VARCHAR, TIMESTAMP, TIMESTAMP, DOUBLE]
# 33                                                                                                                                               [BIGINT, BIGINT, BIGINT, BIGINT, TIMESTAMP, TIMESTAMP, TIMESTAMP, BIGINT, DOUBLE, VARCHAR, DOUBLE, VARCHAR, BIGINT, BIGINT, VARCHAR, BIGINT, DOUBLE]
# 34                                                                  [BIGINT, BIGINT, BIGINT, BIGINT, TIMESTAMP, TIMESTAMP, TIMESTAMP, BIGINT, DOUBLE, VARCHAR, DOUBLE, VARCHAR, BIGINT, BIGINT, VARCHAR, VARCHAR, VARCHAR, VARCHAR, DOUBLE, DOUBLE, VARCHAR, BIGINT, BIGINT, VARCHAR, DOUBLE, DOUBLE]
# 35                                                                                                                                                                                                                    [BIGINT, BIGINT, BIGINT, BIGINT, TIMESTAMP, TIMESTAMP, BIGINT, DOUBLE, VARCHAR]
# 36                                                                                                    [BIGINT, BIGINT, BIGINT, BIGINT, TIMESTAMP, TIMESTAMP, TIMESTAMP, BIGINT, DOUBLE, VARCHAR, VARCHAR, VARCHAR, BIGINT, BIGINT, VARCHAR, VARCHAR, DOUBLE, BIGINT, BIGINT, VARCHAR, DOUBLE, BIGINT]
#
#     temporary
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
# 5       False
# 6       False
# 7       False
# 8       False
# 9       False
# 10      False
# 11      False
# 12      False
# 13      False
# 14      False
# 15      False
# 16      False
# 17      False
# 18      False
# 19      False
# 20      False
# 21      False
# 22      False
# 23      False
# 24      False
# 25      False
# 26      False
# 27      False
# 28      False
# 29      False
# 30      False
# 31      False
# 32      False
# 33      False
# 34      False
# 35      False
# 36      False

# %% [markdown]
# # SQL Explore Data

# %% [markdown]
# ## Patient Data

# %%
# first 5 rows of patients table
df = sql("SELECT * from hosp.patients")
show(df, limit=True)
# Out:
#         subject_id gender  anchor_age  anchor_year anchor_year_group  \
# 0         10000032      F          52         2180       2014 - 2016
# 1         10000048      F          23         2126       2008 - 2010
# 2         10000058      F          33         2168       2020 - 2022
# 3         10000068      F          19         2160       2008 - 2010
# 4         10000084      M          72         2160       2017 - 2019
# ...            ...    ...         ...          ...               ...
# 364622    19999828      F          46         2147       2017 - 2019
# 364623    19999829      F          28         2186       2008 - 2010
# 364624    19999840      M          58         2164       2008 - 2010
# 364625    19999914      F          49         2158       2017 - 2019
# 364626    19999987      F          57         2145       2011 - 2013
#
#               dod
# 0      2180-09-09
# 1             NaT
# 2             NaT
# 3             NaT
# 4      2161-02-13
# ...           ...
# 364622        NaT
# 364623        NaT
# 364624 2164-09-17
# 364625        NaT
# 364626        NaT
#
# [364627 rows x 6 columns]

# %%
# Anzahl Patienten, Aufenthalte
sql("""
SELECT COUNT(DISTINCT subject_id) AS patients,
       COUNT(DISTINCT hadm_id) AS admissions
FROM hosp.admissions;

""")
# Out:
# shape: (1, 2)
# ┌──────────┬────────────┐
# │ patients ┆ admissions │
# │ ---      ┆ ---        │
# │ i64      ┆ i64        │
# ╞══════════╪════════════╡
# │ 223452   ┆ 546028     │
# └──────────┴────────────┘

# %% [markdown]
# ## Diagnosis Data

# %%
# first 5 rows of diagnosis table
df = sql("""SELECT *
         from ed.diagnosis order by icd_code
         """)
show(df,limit=True)
# Out:
#         subject_id   stay_id  seq_num icd_code  icd_version  \
# 0         10427677  35873964        1     0020            9
# 1         11545281  36308244        1     0030            9
# 2         19906243  39205868        1     0059            9
# 3         19732857  35260270        1     0059            9
# 4         18106634  34272117        1     0059            9
# ...            ...       ...      ...      ...          ...
# 899045    11548266  37524655        3    Z9981           10
# 899046    12070608  32123100        3    Z9981           10
# 899047    17396346  35428975        2    Z9981           10
# 899048    16865766  39674308        4    Z9981           10
# 899049    16450946  35513912        4    Z9981           10
#
#                                 icd_title
# 0                           TYPHOID FEVER
# 1                    SALMONELLA ENTERITIS
# 2                      FOOD POISONING NOS
# 3                      FOOD POISONING NOS
# 4                      FOOD POISONING NOS
# ...                                   ...
# 899045  Dependence on supplemental oxygen
# 899046  Dependence on supplemental oxygen
# 899047  Dependence on supplemental oxygen
# 899048  Dependence on supplemental oxygen
# 899049  Dependence on supplemental oxygen
#
# [899050 rows x 6 columns]

# %%
# count of distinct icd titles (diagnoses)
df = sql("""SELECT count(icd_title), icd_title 
         from ed.diagnosis
         group by 2
         order by 1 desc""")
show(df, limit=True)
# Out:
#        count(icd_title)                                          icd_title
# 0                 26816                                   HYPERTENSION NOS
# 1                 21264                   Essential (primary) hypertension
# 2                 13016                            Chest pain, unspecified
# 3                 12398                                     CHEST PAIN NOS
# 4                 12026                             DIABETES UNCOMPL ADULT
# ...                 ...                                                ...
# 13167                 1  Streptococcus, group A, causing diseases class...
# 13168                 1  Displ seg fx shaft of l tibia, init for opn fx...
# 13169                 1  Prsn brd/alit pk-up/van injured in nonclsn trn...
# 13170                 1  Disp fx of body of scapula, right shoulder, in...
# 13171                 1     Poisoning by benzodiazepines, accidental, subs
#
# [13172 rows x 2 columns]

# %%
sql("""SELECT *
         from hosp.d_icd_diagnoses
         -- group by 2
         -- order by 1 desc
         where icd_code like '%0'
         """)
show(df, limit=True)
# Out:
#        count(icd_title)                                          icd_title
# 0                 26816                                   HYPERTENSION NOS
# 1                 21264                   Essential (primary) hypertension
# 2                 13016                            Chest pain, unspecified
# 3                 12398                                     CHEST PAIN NOS
# 4                 12026                             DIABETES UNCOMPL ADULT
# ...                 ...                                                ...
# 13167                 1  Streptococcus, group A, causing diseases class...
# 13168                 1  Displ seg fx shaft of l tibia, init for opn fx...
# 13169                 1  Prsn brd/alit pk-up/van injured in nonclsn trn...
# 13170                 1  Disp fx of body of scapula, right shoulder, in...
# 13171                 1     Poisoning by benzodiazepines, accidental, subs
#
# [13172 rows x 2 columns]

# %%
# count of distinct icd titles (diagnoses)
df = sql("""SELECT *
         from hosp.diagnoses_icd""")
show(df,limit=True)
# Out:
#          subject_id   hadm_id  seq_num icd_code  icd_version
# 0          10000032  22595853        1     5723            9
# 1          10000032  22595853        2    78959            9
# 2          10000032  22595853        3     5715            9
# 3          10000032  22595853        4    07070            9
# 4          10000032  22595853        5      496            9
# ...             ...       ...      ...      ...          ...
# 6364483    19999987  23865745        7    41401            9
# 6364484    19999987  23865745        8    78039            9
# 6364485    19999987  23865745        9     0413            9
# 6364486    19999987  23865745       10    36846            9
# 6364487    19999987  23865745       11     7810            9
#
# [6364488 rows x 5 columns]

# %%
# avg length of stay in days
sql("""
SELECT ROUND(AVG(EXTRACT(EPOCH FROM (dischtime - admittime))/3600/24), 2) AS avg_los_days
FROM hosp.admissions;
""")
# Out:
# shape: (1, 1)
# ┌──────────────┐
# │ avg_los_days │
# │ ---          │
# │ f64          │
# ╞══════════════╡
# │ 4.76         │
# └──────────────┘

# %%
# diagnoses per admission
sql("""
SELECT COUNT(*) / COUNT(DISTINCT hadm_id) AS avg_diagnoses_per_admission
FROM hosp.diagnoses_icd;
""")
# Out:
# shape: (1, 1)
# ┌─────────────────────────────┐
# │ avg_diagnoses_per_admission │
# │ ---                         │
# │ f64                         │
# ╞═════════════════════════════╡
# │ 11.66732                    │
# └─────────────────────────────┘

# %% [markdown]
# # Vizusalization
# Patient Data

# %%
! pip install plotly nbformat
# Out:
# Requirement already satisfied: plotly in ./venv/lib/python3.13/site-packages (6.3.1)
# Requirement already satisfied: nbformat in ./venv/lib/python3.13/site-packages (5.10.4)
# Requirement already satisfied: narwhals>=1.15.1 in ./venv/lib/python3.13/site-packages (from plotly) (2.8.0)
# Requirement already satisfied: packaging in ./venv/lib/python3.13/site-packages (from plotly) (25.0)
# Requirement already satisfied: fastjsonschema>=2.15 in ./venv/lib/python3.13/site-packages (from nbformat) (2.21.2)
# Requirement already satisfied: jsonschema>=2.6 in ./venv/lib/python3.13/site-packages (from nbformat) (4.25.1)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in ./venv/lib/python3.13/site-packages (from nbformat) (5.8.1)
# Requirement already satisfied: traitlets>=5.1 in ./venv/lib/python3.13/site-packages (from nbformat) (5.14.3)
# Requirement already satisfied: attrs>=22.2.0 in ./venv/lib/python3.13/site-packages (from jsonschema>=2.6->nbformat) (25.4.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in ./venv/lib/python3.13/site-packages (from jsonschema>=2.6->nbformat) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in ./venv/lib/python3.13/site-packages (from jsonschema>=2.6->nbformat) (0.37.0)
# Requirement already satisfied: rpds-py>=0.7.1 in ./venv/lib/python3.13/site-packages (from jsonschema>=2.6->nbformat) (0.28.0)
# Requirement already satisfied: platformdirs>=2.5 in ./venv/lib/python3.13/site-packages (from jupyter-core!=5.0.*,>=4.12->nbformat) (4.4.0)
#
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: pip install --upgrade pip
#
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: pip install --upgrade pip

# %% [markdown]
# # Patients

# %%
age_range = sql("""SELECT max(anchor_age) as max_age,
                     min(anchor_age) as min_age,
                     AVG(anchor_age) as avg_age
                from hosp.patients;""")
show(age_range)
# Out:
#    max_age  min_age    avg_age
# 0       91       18  48.875097

# %%
import plotly.express as px
# load patient data
df_patients = sql("SELECT * from hosp.patients;")

# Beispiel: df hat Spalten ["patient_id", "age"]
fig = px.histogram(df_patients, x="anchor_age", nbins=70, title="Age of Patients Histogram")
fig.update_layout(bargap=0.2, xaxis_title="Age", yaxis_title="Count of Patients")
fig.show()

# %%
# patients with admissions and demographics
df = sql("""
    SELECT 
        p.subject_id,
        p.gender,
        p.anchor_age,
        a.race,
        a.admission_type,
        a.admission_location,
        a.insurance,
        a.marital_status,
        a.language
    FROM hosp.patients p
    JOIN hosp.admissions a ON p.subject_id = a.subject_id
""")
show(df,limit=True)
# Out:
#         subject_id gender  anchor_age                    race  admission_type  \
# 0         10876550      M          79                   WHITE        EW EMER.
# 1         10876573      M          32                   WHITE        EW EMER.
# 2         10876693      M          62  BLACK/AFRICAN AMERICAN        EW EMER.
# 3         10876693      M          62  BLACK/AFRICAN AMERICAN  EU OBSERVATION
# 4         10876750      F          73                 UNKNOWN          URGENT
# ...            ...    ...         ...                     ...             ...
# 546023    19341569      M          50  BLACK/AFRICAN AMERICAN  EU OBSERVATION
# 546024    19341569      M          50  BLACK/AFRICAN AMERICAN  EU OBSERVATION
# 546025    19341569      M          50  BLACK/AFRICAN AMERICAN  EU OBSERVATION
# 546026    19341569      M          50  BLACK/AFRICAN AMERICAN  EU OBSERVATION
# 546027    19341569      M          50  BLACK/AFRICAN AMERICAN  EU OBSERVATION
#
#             admission_location insurance marital_status language
# 0               EMERGENCY ROOM  Medicare        MARRIED  English
# 1               EMERGENCY ROOM  Medicaid         SINGLE  English
# 2               EMERGENCY ROOM   Private        MARRIED  English
# 3               EMERGENCY ROOM  Medicare        MARRIED  English
# 4       TRANSFER FROM HOSPITAL  Medicare        MARRIED  English
# ...                        ...       ...            ...      ...
# 546023   WALK-IN/SELF REFERRAL  Medicare         SINGLE  English
# 546024   WALK-IN/SELF REFERRAL  Medicare         SINGLE  English
# 546025   WALK-IN/SELF REFERRAL  Medicare         SINGLE  English
# 546026   WALK-IN/SELF REFERRAL  Medicare         SINGLE  English
# 546027      PHYSICIAN REFERRAL  Medicare         SINGLE  English
#
# [546028 rows x 9 columns]

# %%
import plotly.graph_objects as go
from plotly.subplots import make_subplots
# =============================================================================
# 2. ALTERS- UND GESCHLECHTSVERTEILUNG (POPULATION PYRAMID)
# =============================================================================
age_bins = [0, 18, 30, 40, 50, 60, 70, 80, 90, 100, 120]
df_pyramid = df.with_columns(
    pl.col("anchor_age").cut(age_bins).alias("age_group")
)

pyramid_data = (df_pyramid
    .group_by(["age_group", "gender"])
    .agg(pl.count().alias("count"))
    .sort("age_group")
)

# Erstelle Population Pyramid
male_data = pyramid_data.filter(pl.col("gender") == "M")
female_data = pyramid_data.filter(pl.col("gender") == "F")

fig1 = go.Figure()
fig1.add_trace(go.Bar(
    y=male_data["age_group"].cast(str).to_list(),
    x=[-x for x in male_data["count"].to_list()],  # Konvertiere zu Liste für Negation
    name='Male',
    orientation='h',
    marker=dict(color='steelblue')
))
fig1.add_trace(go.Bar(
    y=female_data["age_group"].cast(str).to_list(),
    x=female_data["count"].to_list(),
    name='Female',
    orientation='h',
    marker=dict(color='salmon')
))

fig1.update_layout(
    title='Population Pyramid: Age and Gender Distribution',
    barmode='relative',
    bargap=0.1,
    xaxis_title='Number of Patients',
    yaxis_title='Age Group',
    height=600
)
fig1.show()
# Out:
# /var/folders/z6/l14kg6kd267dqw00p40_86jc0000gn/T/ipykernel_42182/2739793193.py:13: DeprecationWarning:
#
# `pl.count()` is deprecated. Please use `pl.len()` instead.
# (Deprecated in version 0.20.5)

# %% [markdown]
# # Diagnosis

# %%
# sql query to get diagnosis data
df = sql("""SELECT count(icd_title) as count, icd_title 
         from ed.diagnosis
         group by 2
         order by 1 desc limit 20;""")

# Top 20 most frequent diagnoses

fig1 = px.bar(df, x="count", y="icd_title", 
              title="Top 20 Most Frequent Diagnoses",
              orientation='h')
fig1.update_layout(yaxis={'categoryorder':'total ascending'}, 
                   height=600, yaxis_title="", xaxis_title="Number of Cases")
fig1.show()
